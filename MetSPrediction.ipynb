# %% [markdown]
# # Metabolic Syndrome Prediction
# Project 4
#
#
# *Christina Brockway*
#
# ## Business Understanding
#
#
# **Stakeholder Needs:**
# To look at common risk factors and use a machine learning model to predict the likelihood of someone having metabolic syndrome.
#
#
# **Metabolic Syndrome Prediction**
# - *Other Names:* Syndrome X, Insulin Resistance Syndrome, Dysmetabolic Syndrome
# - *Definition:*  A cluster of conditions that cause and increased risk for heart disease, stroke, and diabetes
#
# According to the Mayo Clinic, metabolic syndrome will  cause an increase in the risk of heart disease, stroke, and type 2 diabetes.  This syndrome is caused by the presence of multiple risk factors such as body mass index, waist circumference, cholesterol levels, age,  and other various factors.  The National Heart, Lung, and Blood Institue says the syndrome is found in about 1 in 3 adults making it farily common. A diagnosis of metabolic syndrome, although eye opening, doesn't mean patients are definitively getting diabetes or having a stroke. With the right diet and healthy lifestyle changes, metabolic syndrome is preventable, thus showing the importantance of identifying it.
#
# The goal of this projest is to use a series of risk factors, and create a model that can predict the likihood of metabolic syndrome in patients. The dataset provided came from the NHANES initiative.  It contains variables including: waist circumference, triglyerades, cholesterol levels, race, income, uric acid levels, age, gender, marital status, body mass index, urine albumin grades and rates, and blood glucose levels.
#
# The target for this dataset is the metabolic syndrome feature.  SEQN will be set as the index as it is a unique identifier.  There are 2401 records representing a person and their attributes of which there are 13. There are some columns that have null values needing to be imputed. The feature 'UrAlbCr' was not defined and and assumption was made as to what is being represented based on the NIH and Cleavland Clinic websites. Aside from "UrAlbCr" not being defined, there don't appear to be any chanllenges with the dataset that would interfere with modeling.

# %% [markdown]
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-0pky{border-color:inherit;text-align:left;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-0pky" colspan="5"><span style="font-weight:bold;font-style:italic">Data Dictionary for Metabolic Syndrome Dataset </span></th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-0pky"><span style="font-weight:bold">Feature</span></td>
#     <td class="tg-0pky"><span style="font-weight:bold">dtype</span></td>
#     <td class="tg-0pky"><span style="font-weight:bold">Expected Range</span></td>
#     <td class="tg-0pky"><span style="font-weight:bold">Definition</span></td>
#     <td class="tg-0pky"><span style="font-weight:bold;font-style:italic">cat, num, ord</span></td>
#   </tr>
#   <tr>
#     <td class="tg-0pky"><span style="font-weight:bold;font-style:italic">seqn</span></td>
#     <td class="tg-0pky">int</td>
#     <td class="tg-0pky">#</td>
#     <td class="tg-0pky">sequential identification number</td>
#     <td class="tg-0pky"><span style="font-weight:bold;font-style:italic">Index?</span></td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">Age</td>
#     <td class="tg-0pky">int</td>
#     <td class="tg-0pky">20-80</td>
#     <td class="tg-0pky">age of individual<br></td>
#     <td class="tg-0pky">num</td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">Sex</td>
#     <td class="tg-0pky">str</td>
#     <td class="tg-0pky">Male<br>Female</td>
#     <td class="tg-0pky">gender of individual</td>
#     <td class="tg-0pky">cat</td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">Marital</td>
#     <td class="tg-0pky">str</td>
#     <td class="tg-0pky">Married<br>Single<br>Divorced<br>Widowed<br>Separated</td>
#     <td class="tg-0pky">marital status</td>
#     <td class="tg-0pky">cat</td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">Income</td>
#     <td class="tg-0pky">int</td>
#     <td class="tg-0pky">#</td>
#     <td class="tg-0pky">income information</td>
#     <td class="tg-0pky">num</td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">Race</td>
#     <td class="tg-0pky">str</td>
#     <td class="tg-0pky">Other<br>MexAmerican<br>Hispanic<br>Asian<br>Black<br>White</td>
#     <td class="tg-0pky">race of individual</td>
#     <td class="tg-0pky">cat</td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">WaistCirc</td>
#     <td class="tg-0pky">float</td>
#     <td class="tg-0pky">risk factor(cm): Men, Women<br>low: &lt; 94m,&nbsp;&nbsp;80w<br>high: 94-102m, 80-88w<br>very high: &gt; 102m, 88w</td>
#     <td class="tg-0pky">Circumference of the waist</td>
#     <td class="tg-0pky">num</td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">BMI</td>
#     <td class="tg-0pky">float</td>
#     <td class="tg-0pky">Underweight:&lt; 18.5<br>Normal:18.5-24.9<br>Overweight: 25-29.9<br>Obese: &gt; 30<br></td>
#     <td class="tg-0pky">body mass index, a measurement of body composition using height and weight </td>
#     <td class="tg-0pky">num</td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">Albuminuria</td>
#     <td class="tg-0pky">int</td>
#     <td class="tg-0pky">0<br>1<br>2</td>
#     <td class="tg-0pky">aka proteinuria<br>a scale grading levels of albumin in urine<br><span style="font-weight:bold">A1: &lt;10-30 Normal or mildly elevated </span><br><span style="font-weight:bold">A2:  30-300 moderately elevated</span><br><span style="font-weight:bold">A3:  &gt;300 albuminuria</span></td>
#     <td class="tg-0pky">ord<br></td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">UrAlbCr</td>
#     <td class="tg-0pky">float</td>
#     <td class="tg-0pky">A1: &lt;30 Normal or mildly elevated <br>A2:  30-300 moderately elevated<br>A3:  &gt;300 albuminuria<br></td>
#     <td class="tg-0pky">UACR - ratio of the levels of albumin and creatin in urine</td>
#     <td class="tg-0pky">num</td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">UricAcid</td>
#     <td class="tg-0pky">float</td>
#     <td class="tg-0pky">Normal female: &gt;6mg/dL<br>Normal male: &gt;7 mg/dL</td>
#     <td class="tg-0pky">measures amount of uric acid in blood<br>Uric acid is a normal body waste product<br>too high may mean kidneys are not working properly</td>
#     <td class="tg-0pky">num</td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">BloodGlucose</td>
#     <td class="tg-0pky">int</td>
#     <td class="tg-0pky">Normal 80-130mg/dL</td>
#     <td class="tg-0pky">Level of glucose in blood<br>too low or too high indicated blood sugar control issues</td>
#     <td class="tg-0pky">num</td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">HDL</td>
#     <td class="tg-0pky">int</td>
#     <td class="tg-0pky">Normal male:  &lt; 40mg/dL <br>Normal female: &lt;50mg/dL</td>
#     <td class="tg-0pky">"good" cholesterol levels in blood<br>a lower HDL means higher risk for heart attack</td>
#     <td class="tg-0pky">num</td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">Triglycerides</td>
#     <td class="tg-0pky">int</td>
#     <td class="tg-0pky">150-199 mg/dL borderline<br>200-499 mg/dL high<br>&gt;500 mg/dL very high</td>
#     <td class="tg-0pky">amount of triglycerides in blood<br>high levels means risk for stroke or heart attack</td>
#     <td class="tg-0pky">num</td>
#   </tr>
#   <tr>
#     <td class="tg-0pky"><span style="font-weight:bold;font-style:italic">MetabolicSyndrome</span></td>
#     <td class="tg-0pky">str</td>
#     <td class="tg-0pky">No MetSyn<br>MetSyn</td>
#     <td class="tg-0pky">does the individual have metabolic syndrome</td>
#     <td class="tg-0pky"><span style="font-weight:bold;font-style:italic">target</span></td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# The following sources were used to research the dataset and create this dictionary.  The only issue was the 'UrAlbCre' feature.  After researching the various tests done for metabolic syndrome and the values provided, it is assumed that 'UrAlbCr' is UACR.  UACR is a measure of the ratio of albumin to creatin in urine, and is used to detect kidney disease.
#
# Images:  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC9479724/
#
# https://www.urmc.rochester.edu/encyclopedia/
#
# https://www.nhlbi.nih.gov/health/metabolic-syndrome/diagnosis
#
# https://my.clevelandclinic.org/health/diseases/10783-metabolic-syndrome
#
# https://www.kidney.org/content/kidney-failure-risk-factor-urine-albumin-to-creatinine-ration-uacr

# %% [markdown]
# **Using the dataset found on Dataworld:**
# https://data.world/informatics-edu/metabolic-syndrome-prediction

# %% [markdown]
# ### Task:
#
# * Explore/clean the data
# * Exploratory Visualizations
#     *  Search for trends
# *  Choose a model
#     *  Preprocess data
#     *  Fit and evaluated a default model
#     *  Extract and visualize the top 10 features using permutation importance
#     *  Answer: Do these features make sense based on the business case?
# * Create explanatory visualizations for the most important features
#     *  Select 2 of the top 10 features from permutation importances and produce explanatory visualizations showing relationship to the target
#     *  Demonstrate key trends  that are intrest to a stkeholder
#        - add these to readme

# %% [markdown]
# ### Load Dataset

# %% [markdown]
# #### Imports

# %%
# Imports
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import missingno as msno

##Preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder
from sklearn.compose import make_column_transformer,  make_column_selector, ColumnTransformer

##Models
from sklearn.tree import DecisionTreeClassifier


#Metrics
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, classification_report, confusion_matrix, ConfusionMatrixDisplay

# Set pandas as the default output for sklearn
from sklearn import set_config
set_config(transform_output='pandas',
           display='diagram')

# %%
#Define Custom Functions

def classification_metrics(y_true, y_pred, label='',
                           output_dict=False, figsize=(8,4),
                           normalize='true', cmap='Blues',
                           colorbar=False):
    # Get the classification report
    report = classification_report(y_true, y_pred)
    ## Print header and report
    header = "-"*70
    print(header, f" Classification Metrics: {label}", header, sep='\n')
    print(report)
    ## CONFUSION MATRICES SUBPLOTS
    fig, axes = plt.subplots(ncols=2, figsize=figsize)
    # create a confusion matrix  of raw counts
    ConfusionMatrixDisplay.from_predictions(y_true, y_pred,
                normalize=None, cmap='gist_gray', colorbar=colorbar,
                ax = axes[0],);
    axes[0].set_title("Raw Counts")
    # create a confusion matrix with the test data
    ConfusionMatrixDisplay.from_predictions(y_true, y_pred,
                normalize=normalize, cmap=cmap, colorbar=colorbar,
                ax = axes[1]);
    axes[1].set_title("Normalized Confusion Matrix")
    # Adjust layout and show figure
    fig.tight_layout()
    plt.show()
    # Return dictionary of classification_report
    if output_dict==True:
        report_dict = classification_report(y_true, y_pred, output_dict=True)
        return report_dict


def evaluate_classification(model, X_train, y_train, X_test, y_test,
                         figsize=(6,4), normalize='true', output_dict = False,
                            cmap_train='Blues', cmap_test="Reds",colorbar=False):
    # Get predictions for training data
    y_train_pred = model.predict(X_train)
    # Call the helper function to obtain regression metrics for training data
    results_train = classification_metrics(y_train, y_train_pred, #verbose = verbose,
                                     output_dict=True, figsize=figsize,
                                         colorbar=colorbar, cmap=cmap_train,
                                     label='Training Data')
    print()
    # Get predictions for test data
    y_test_pred = model.predict(X_test)
    # Call the helper function to obtain regression metrics for test data
    results_test = classification_metrics(y_test, y_test_pred, #verbose = verbose,
                                  output_dict=True,figsize=figsize,
                                         colorbar=colorbar, cmap=cmap_test,
                                    label='Test Data' )
    if output_dict == True:
        # Store results in a dataframe if ouput_frame is True
        results_dict = {'train':results_train,
                    'test': results_test}
        return results_dict

# %%
#EDA Functions
"""UNIVARIATE PLOTTING FUNCTIONS FOR EDA"""
# Add the print statements to the function
def explore_categorical(df2, x, fillna = True, placeholder = 'MISSING',
                        figsize = (6,4), order = None):
  """Creates a seaborn countplot with the option to temporarily fill missing values
  Prints statements about null values, cardinality, and checks for
  constant/quasi-constant features.
  Source:{PASTE IN FINAL LESSON LINK}
  """
  # Make a copy of the dataframe and fillna
  temp_df = df2.copy()
  # Before filling nulls, save null value counts and percent for printing
  null_count = temp_df[x].isna().sum()
  null_perc = null_count/len(temp_df)* 100
  # fillna with placeholder
  if fillna == True:
    temp_df[x] = temp_df[x].fillna(placeholder)
  # Create figure with desired figsize
  fig, ax = plt.subplots(figsize=figsize)
  # Plotting a count plot
  sns.countplot(data=temp_df, x=x, ax=ax, order=order)
  # Rotate Tick Labels for long names
  ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
  # Add a title with the feature name included
  ax.set_title(f"Column: {x}", fontweight='bold')

  # Fix layout and show plot (before print statements)
  fig.tight_layout()
  plt.show()

  # Print null value info
  print(f"- NaN's Found: {null_count} ({round(null_perc,2)}%)")
  # Print cardinality info
  nunique = temp_df[x].nunique()
  print(f"- Unique Values: {nunique}")
  # First find value counts of feature
  val_counts = temp_df[x].value_counts(dropna=False)
  # Define the most common value
  most_common_val = val_counts.index[0]
  # Define the frequency of the most common value
  freq = val_counts.values[0]
  # Calculate the percentage of the most common value
  perc_most_common = freq / len(temp_df) * 100
  # Print the results
  print(f"- Most common value: '{most_common_val}' occurs {freq} times ({round(perc_most_common,2)}%)")
  # print message if quasi-constant or constant (most common val more than 98% of data)
  if perc_most_common > 98:
    print(f"\n- [!] Warning: '{x}' is a constant or quasi-constant feature and should be dropped.")
  else:
    print("- Not constant or quasi-constant.")
  return fig, ax


# TO DO: add the new print statements from explore_categorical
def explore_numeric(df2, x, figsize=(6,5) ):
  """Creates a seaborn histplot and boxplot with a share x-axis,
  Prints statements about null values, cardinality, and checks for
  constant/quasi-constant features.
  Source:{PASTE IN FINAL LESSON LINK}
  """

  ## Save null value counts and percent for printing
  null_count = df2[x].isna().sum()
  null_perc = null_count/len(df)* 100


  ## Making our figure with gridspec for subplots
  gridspec = {'height_ratios':[0.7,0.3]}
  fig, axes = plt.subplots(nrows=2, figsize=figsize,
                           sharex=True, gridspec_kw=gridspec)
  # Histogram on Top
  sns.histplot(data=df2, x=x, ax=axes[0])

  # Boxplot on Bottom
  sns.boxplot(data=df2, x=x, ax=axes[1])

  ## Adding a title
  axes[0].set_title(f"Column: {x}", fontweight='bold')

  ## Adjusting subplots to best fill Figure
  fig.tight_layout()

  # Ensure plot is shown before message
  plt.show()


  # Print null value info
  print(f"- NaN's Found: {null_count} ({round(null_perc,2)}%)")
  # Print cardinality info
  nunique = df[x].nunique()
  print(f"- Unique Values: {nunique}")


  # Get the most most common value, its count as # and as %
  most_common_val_count = df2[x].value_counts(dropna=False).head(1)
  most_common_val = most_common_val_count.index[0]
  freq = most_common_val_count.values[0]
  perc_most_common = freq / len(df) * 100

  print(f"- Most common value: '{most_common_val}' occurs {freq} times ({round(perc_most_common,2)}%)")

  # print message if quasi-constant or constant (most common val more than 98% of data)
  if perc_most_common > 98:
    print(f"\n- [!] Warning: '{x}' is a constant or quasi-constant feature and should be dropped.")
  else:
    print("- Not constant or quasi-constant.")
  return fig, axes

# %%
# Updating function
def plot_categorical_vs_target(df2, x, y, figsize=(6,4),
                            fillna = True, placeholder = 'MISSING',
                            order = None, target_type='reg'):
  # Make a copy of the dataframe and fillna
  temp_df = df2.copy()
  # fillna with placeholder
  if fillna == True:
    temp_df[x] = temp_df[x].fillna(placeholder)
  # or drop nulls prevent unwanted 'nan' group in stripplot
  else:
    temp_df = temp_df.dropna(subset=[x])
  # Create the figure and subplots
  fig, ax = plt.subplots(figsize=figsize)
  # REGRESSION-TARGET PLOT
  if target_type=='reg': #Added if statement here
    # Barplot
    sns.barplot(data=temp_df, x=x, y=y, ax=ax, order=order, alpha=0.6,
                linewidth=1, edgecolor='black', errorbar=None)
    # Boxplot
    sns.stripplot(data=temp_df, x=x, y=y, hue=x, ax=ax,
                  order=order, hue_order=order, legend=False,
                  edgecolor='white', linewidth=0.5,
                  size=3,zorder=0)
  # CLASSIFICATION-TARGET PLOT # This is the new code for the classification task
  elif target_type=='class':
    ax = sns.histplot(data=temp_df, x=x, hue=y, stat='percent',  multiple='fill')
  # Rotate xlabels
  ax.set_xticks(ax.get_xticks()) # Added this to prevent a bug
  ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
  # Add a title
  ax.set_title(f"{x} vs. {y}")
  fig.tight_layout()
  return fig, ax

# %%
##EDA Mulitvariate function

def plot_numeric_vs_target(df2, x, y, figsize=(6,4),
                           target_type='reg', estimator='mean',
                           errorbar='ci',sorted=False,ascending=False,
                           **kwargs): # kwargs for sns.regplot

  nulls = df[[x,y]].isna().sum()
  if nulls.sum()>0:
    print(f"- Excluding {nulls.sum()} NaN's")
    # print(nulls)
    temp_df = df2.dropna(subset=[x,y,])
  else:
    temp_df = df2
  # Create the figure
  fig, ax = plt.subplots(figsize=figsize)

  # REGRESSION-TARGET PLOT
  if 'reg' in target_type:
    # Calculate the correlation
    corr = df2[[x,y]].corr().round(2)
    r = corr.loc[x,y]
    # Plot the data
    scatter_kws={'ec':'white','lw':1,'alpha':0.8}
    sns.regplot(data=temp_df, x=x, y=y, ax=ax, scatter_kws=scatter_kws, **kwargs) # Included the new argument within the sns.regplot function
    ## Add the title with the correlation
    ax.set_title(f"{x} vs. {y} (r = {r})")

  # CLASSIFICATION-TARGET PLOT
  elif 'class' in target_type:

    # Sort the groups by median/mean
    if sorted == True:

      if estimator == 'median':
        group_vals = temp_df.groupby(y)[x].median()
      elif estimator =='mean':
        group_vals = temp_df.groupby(y)[x].mean()

      ## Sort values
      group_vals = group_vals.sort_values(ascending=ascending)
      order = group_vals.index

    else:
      # Set order to None if not calcualted
      order = None


    # Left Subplot (barplot)
    sns.barplot(data=temp_df, x=y, y=x, order=order,  estimator=estimator,
                errorbar=errorbar, ax=ax, **kwargs)

    # Add title
    ax.set_title(f"{x} vs. {y}")

    # rotate xaxis labels
    ax.set_xticks(ax.get_xticks())
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')


  # Final Adjustments & return
  fig.tight_layout()
  fig.show()
  return fig, ax

# %%
data = pd.read_csv("data/Metabolic  Syndrome.csv")
data = data.set_index('seqn')
data.head()
# Out:
#        Age     Sex  Marital  Income   Race  WaistCirc   BMI  Albuminuria  \
# seqn
# 62161   22    Male   Single  8200.0  White       81.0  23.3            0
# 62164   44  Female  Married  4500.0  White       80.1  23.2            0
# 62169   21    Male   Single   800.0  Asian       69.6  20.1            0
# 62172   43  Female   Single  2000.0  Black      120.4  33.3            0
# 62177   51    Male  Married     NaN  Asian       81.1  20.1            0
#
#        UrAlbCr  UricAcid  BloodGlucose  HDL  Triglycerides MetabolicSyndrome
# seqn
# 62161     3.88       4.9            92   41             84         No MetSyn
# 62164     8.55       4.5            82   28             56         No MetSyn
# 62169     5.07       5.4           107   43             78         No MetSyn
# 62172     5.22       5.0           104   73            141         No MetSyn
# 62177     8.13       5.0            95   43            126         No MetSyn

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2401 entries, 62161 to 71915
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Age                2401 non-null   int64
#  1   Sex                2401 non-null   object
#  2   Marital            2193 non-null   object
#  3   Income             2284 non-null   float64
#  4   Race               2401 non-null   object
#  5   WaistCirc          2316 non-null   float64
#  6   BMI                2375 non-null   float64
#  7   Albuminuria        2401 non-null   int64
#  8   UrAlbCr            2401 non-null   float64
#  9   UricAcid           2401 non-null   float64
#  10  BloodGlucose       2401 non-null   int64
#  11  HDL                2401 non-null   int64
#  12  Triglycerides      2401 non-null   int64
#  13  MetabolicSyndrome  2401 non-null   object
# dtypes: float64(5), int64(5), object(4)
# memory usage: 281.4+ KB

# %% [markdown]
# ### Clean Data:

# %% [markdown]
# #### Check for Duplicates

# %%
df=data.copy()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (2401, 14)

# %% [markdown]
# #### Check for Consistency

# %%
df.nunique()
# Out:
# Age                    61
# Sex                     2
# Marital                 5
# Income                 14
# Race                    6
# WaistCirc             635
# BMI                   322
# Albuminuria             3
# UrAlbCr              1383
# UricAcid               88
# BloodGlucose          187
# HDL                    93
# Triglycerides         345
# MetabolicSyndrome       2
# dtype: int64

# %% [markdown]
# ***Initial Observations***
# * There are 2401 rows
# * There are 13 features
# * seqn was set as index
# * Marital, WaistCirc, Income, and BMI have null values
# * There are the expected number of unique values for the features
# * Will rename columns for ease
# * What is UrAlbCr?
# * There are the following dtypes:
#   * float64(5), int64(5), object(4)
#   * Albuminaria - is this dtype wrong?

# %%
df.describe()
# Out:
#                Age       Income    WaistCirc          BMI  Albuminuria  \
# count  2401.000000  2284.000000  2316.000000  2375.000000  2401.000000
# mean     48.691795  4005.253940    98.307254    28.702189     0.154102
# std      17.632852  2954.032186    16.252634     6.662242     0.422780
# min      20.000000   300.000000    56.200000    13.400000     0.000000
# 25%      34.000000  1600.000000    86.675000    24.000000     0.000000
# 50%      48.000000  2500.000000    97.000000    27.700000     0.000000
# 75%      63.000000  6200.000000   107.625000    32.100000     0.000000
# max      80.000000  9000.000000   176.000000    68.700000     2.000000
#
#            UrAlbCr     UricAcid  BloodGlucose          HDL  Triglycerides
# count  2401.000000  2401.000000   2401.000000  2401.000000    2401.000000
# mean     43.626131     5.489046    108.247813    53.369429     128.125364
# std     258.272829     1.439358     34.820657    15.185537      95.322477
# ...

# %% [markdown]
# * Check the following values:
#
#   - tryglycerides 1562 --> possible but improbable
#   - 156 HDL--> possible
#   - 5982 UrAlbCr --> impossible value?
#     - A1: <10-30 Normal or mildly elevated
#     - A2: 30-300 moderately elevated
#     - A3: >300 albuminuria

# %%
# drop 5982 record
df3= df.drop(df[df['UrAlbCr'] <30].index)
df3.shape
# Out:
# (312, 14)

# %%
df4= df.drop(df[df['UrAlbCr'] >300].index)
df4.shape
# Out:
# (2343, 14)

# %%
#correlation between "AlbLevel" and "Albuminuria"
print(df['UrAlbCr'].corr(df['Albuminuria']))
# Out:
# 0.5362135437279103

# %% [markdown]
# * There are 312 records with a normal range of "AlbLevel"
# * There are 2343 records with greater than the moderately elevated "AlbLevels"
# * There is a 53% correlation between "AlbLevel" and "AlbRating"
# * The assumption was made that "UrAlbCr" was the UACR. There should be a direct correlation between the UACR and the albumin rating.
# * Because this column is not well defined in the data dictionary, and does not follow expected correlation of assumption, this column will be dropped to prevent confusion.

# %%
df=df.drop(columns='UrAlbCr')

# %%
df.describe(exclude='number')
# Out:
#            Sex  Marital   Race MetabolicSyndrome
# count     2401     2193   2401              2401
# unique       2        5      6                 2
# top     Female  Married  White         No MetSyn
# freq      1211     1192    933              1579

# %% [markdown]
# ***The datatype for 'Albuminuria' needs to be changed to int.  It is an ordinal number not a float.**

# %% [markdown]
# df['Albuminuria']=df['Albuminuria'].astype(object)

# %%
df['Albuminuria'].dtype
# Out:
# dtype('int64')

# %%
# Rename columns to make life easier
rename_dict = {'MetabolicSyndrome': 'MetS', 'WaistCirc': 'Waist', 'BloodGlucose': 'Glucose',
               'Albuminuria': 'AlbRating'}
df = df.rename(rename_dict, axis=1)
df.head(2)
# Out:
#        Age     Sex  Marital  Income   Race  Waist   BMI  AlbRating  UricAcid  \
# seqn
# 62161   22    Male   Single  8200.0  White   81.0  23.3          0       4.9
# 62164   44  Female  Married  4500.0  White   80.1  23.2          0       4.5
#
#        Glucose  HDL  Triglycerides       MetS
# seqn
# 62161       92   41             84  No MetSyn
# 62164       82   28             56  No MetSyn

# %% [markdown]
# #### Check for null values

# %%
df.isna().sum()
# Out:
# Age                0
# Sex                0
# Marital          208
# Income           117
# Race               0
# Waist             85
# BMI               26
# AlbRating          0
# UricAcid           0
# Glucose            0
# HDL                0
# Triglycerides      0
# MetS               0
# dtype: int64

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %% [markdown]
# #### Save Cleaned Dataframe

# %%
df.to_csv(f'data/clean_MetS.csv', index=True)

# %% [markdown]
# #### Isolate columns by dtype to impute nulls for exploratory analysis

# %%
#Make a df2 to use for exploratory analysis
df2=df.copy()

# %%
cat_cols = df2.select_dtypes('object').columns
cat_cols
# Out:
# Index(['Sex', 'Marital', 'Race', 'MetS'], dtype='object')

# %%
ord_cols = df2['AlbRating']
ord_cols
# Out:
# seqn
# 62161    0
# 62164    0
# 62169    0
# 62172    0
# 62177    0
#         ..
# 71901    0
# 71904    0
# 71909    0
# 71911    0
# 71915    0
# Name: AlbRating, Length: 2401, dtype: int64

# %%
num_cols = df2.select_dtypes('number')
num_cols.describe()
# Out:
#                Age       Income        Waist          BMI    AlbRating  \
# count  2401.000000  2284.000000  2316.000000  2375.000000  2401.000000
# mean     48.691795  4005.253940    98.307254    28.702189     0.154102
# std      17.632852  2954.032186    16.252634     6.662242     0.422780
# min      20.000000   300.000000    56.200000    13.400000     0.000000
# 25%      34.000000  1600.000000    86.675000    24.000000     0.000000
# 50%      48.000000  2500.000000    97.000000    27.700000     0.000000
# 75%      63.000000  6200.000000   107.625000    32.100000     0.000000
# max      80.000000  9000.000000   176.000000    68.700000     2.000000
#
#           UricAcid      Glucose          HDL  Triglycerides
# count  2401.000000  2401.000000  2401.000000    2401.000000
# mean      5.489046   108.247813    53.369429     128.125364
# std       1.439358    34.820657    15.185537      95.322477
# min       1.800000    39.000000    14.000000      26.000000
# ...

# %% [markdown]
# ### Impute Nulls for Analysis

# %%
cat_cols.isna().sum()
# Out:
# 0

# %%
#replace the null value with missing
df2['Marital'] = df2['Marital'].fillna('Missing')
df2['Marital'].value_counts(dropna = False)
# Out:
# Married      1192
# Single        498
# Divorced      242
# Missing       208
# Widowed       166
# Separated      95
# Name: Marital, dtype: int64

# %%
num_cols.isna().sum()
# Out:
# Age                0
# Income           117
# Waist             85
# BMI               26
# AlbRating          0
# UricAcid           0
# Glucose            0
# HDL                0
# Triglycerides      0
# dtype: int64

# %%
#impute num_cols with mean
df2['Income'] = df2['Income'].fillna(df['Income'].mean())
df2['Waist'] = df2['Waist'].fillna(df2['Waist'].mean())
df2['BMI'] = df2['BMI'].fillna(df2['BMI'].mean())

# %%
ord_cols.isna().sum()
# Out:
# 0

# %%
msno.matrix(df2);

# %% [markdown]
# ### Explore Data:

# %%
#Make a for loop to show countplots of cat_cols
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(15,8))
plt.subplots_adjust(hspace=0.5)

for col, ax in zip(cat_cols, axs.ravel()):
  sns.countplot(data = df2, y= df2[col], ax=ax)
  ax.set_title(f'Frequency of {col}')

plt.tight_layout()

# %% [markdown]
# ##### Observations:
# * The target shows about 1/3 have metabolic syndrome.
# * Males and females look to be about evenly represented.
# * The majority of participants were married.
# * The majority of the participants were white followed by black followed by other races
# * Nothing obviously stands out about these features in relation to the target here.

# %%
explore_numeric(df2, 'Age');
# Out:
# - NaN's Found: 0 (0.0%)
# - Unique Values: 61
# - Most common value: '80' occurs 124 times (5.16%)
# - Not constant or quasi-constant.

# %%
explore_numeric(df2, 'Income');
# Out:
# - NaN's Found: 0 (0.0%)
# - Unique Values: 14
# - Most common value: '9000.0' occurs 337 times (14.04%)
# - Not constant or quasi-constant.

# %%
explore_numeric(df2, 'Waist');
# Out:
# - NaN's Found: 0 (0.0%)
# - Unique Values: 635
# - Most common value: '98.30725388601036' occurs 85 times (3.54%)
# - Not constant or quasi-constant.

# %%
explore_numeric(df2, 'BMI');
# Out:
# - NaN's Found: 0 (0.0%)
# - Unique Values: 322
# - Most common value: '28.702189473684214' occurs 26 times (1.08%)
# - Not constant or quasi-constant.

# %%
explore_numeric(df2, 'UricAcid');
# Out:
# - NaN's Found: 0 (0.0%)
# - Unique Values: 88
# - Most common value: '5.2' occurs 77 times (3.21%)
# - Not constant or quasi-constant.

# %%
explore_numeric(df2, 'Glucose');
# Out:
# - NaN's Found: 0 (0.0%)
# - Unique Values: 187
# - Most common value: '97' occurs 90 times (3.75%)
# - Not constant or quasi-constant.

# %%
explore_numeric(df2, 'HDL');
# Out:
# - NaN's Found: 0 (0.0%)
# - Unique Values: 93
# - Most common value: '48' occurs 87 times (3.62%)
# - Not constant or quasi-constant.

# %%
explore_numeric(df2, 'Triglycerides');
# Out:
# - NaN's Found: 0 (0.0%)
# - Unique Values: 345
# - Most common value: '75' occurs 34 times (1.42%)
# - Not constant or quasi-constant.

# %%
explore_categorical(df2, 'AlbRating');
# Out:
# - NaN's Found: 0 (0.0%)
# - Unique Values: 3
# - Most common value: '0' occurs 2089 times (87.01%)
# - Not constant or quasi-constant.

# %% [markdown]
# ##### Relationship to Target

# %%
# Make correlation heatmap for numeric features

#Get correlations
corr=df.corr(numeric_only=True)
corr.round(2)
matrix= np.triu(corr)

plt.figure(figsize=(8,8))
ax= sns.heatmap(corr, annot=True, cmap='coolwarm', mask = matrix);
ax.set_title('Correlation of Numeric Values');

# %% [markdown]
# ##### Observations:
# * There are significant correlation between BMI and Waist
# * Correlation between Uric Acid levels and Waist
# * Negative correlation between HDL and Waist
# * Negative correlation between HDL and Triglycerides

# %%
ax=sns.countplot(data=df2, hue='AlbRating', x= 'MetS')
ax.set_title(f'Albumin Rating vs Metabolic Syndrome');

# %% [markdown]
# *  Albumin Rating and the liklihood of having MetS appear  not to be directly connected
# *  Will use this feature in model

# %%
ax=sns.countplot(data=df2, x='MetS', hue= 'Marital')
ax.set_title(f'Marital Status vs Metabolic Syndrome');

# %% [markdown]
# *  Marital Status appears to be a factor in the liklihood of having MetS
# *  Will use this feature in model

# %%
ax=sns.countplot(data=df2, x='MetS', hue= 'Race')
ax.set_title(f'Race vs Metabolic Syndrome');

# %% [markdown]
# *  A person's race may or may not determine their liklihod of having MetS
# *  Will consider not using this feature in model

# %%
ax=sns.stripplot(data=df2, hue='MetS', x='Age')
ax.set_title(f'Age vs Metabolic Syndrome');

# %% [markdown]
# *  Age appears to be a factor in the liklihood of having MetS
# *  The older the person the higher the chance of MetS
# *  Will use this feature in model

# %%
ax=sns.stripplot(data=df2, hue='MetS', x='Income')
ax.set_title(f'Income vs Metabolic Syndrome');

# %% [markdown]
# *  A person's income may or may not determine their liklihod of having MetS
# *  Will consider not using this feature in model

# %%
ax=sns.stripplot(data=df2, hue='MetS', x='Waist')
ax.set_title(f'Waist vs Metabolic Syndrome');

# %% [markdown]
# *  Waist size appears to be a factor in the liklihood of having MetS
# *  The larger the person's waist the higher the chance of MetS
# *  Will use this feature in model

# %%
ax=sns.stripplot(data=df2, hue='MetS', x='BMI')
ax.set_title(f'BMI vs Metabolic Syndrome');

# %% [markdown]
# *  BMI appears to be a factor in the liklihood of having MetS
# *  The higher the person's BMI the higher the chance of MetS
# *  Will use this feature in model

# %%
ax=sns.stripplot(data=df2, hue='MetS', x='UricAcid')
ax.set_title(f'UricAcid vs Metabolic Syndrome');

# %% [markdown]
# *  A person's UricAcid levels may or may not determine their liklihod of having MetS
# *  Will consider not using this feature in model

# %%
ax=sns.stripplot(data=df2, hue='MetS', x='Glucose')
ax.set_title(f'Glucose vs Metabolic Syndrome');

# %% [markdown]
# *  Glucose level appears to be a factor in the liklihood of having MetS
# *  The higher the person's levels of glucose in their blood the higher the chance of MetS
# *  Will use this feature in model

# %%
ax=sns.stripplot(data=df2, hue='MetS', x='HDL')
ax.set_title(f'HDL vs Metabolic Syndrome');

# %% [markdown]
# *  HDL level appears to be a factor in the liklihood of not having MetS
# *  The higher the person's HDL levels the lower the chance of MetS
# *  Will use this feature in model

# %%
ax=sns.stripplot(data=df2, hue='MetS', x='Triglycerides')
ax.set_title(f'Triglycerides vs Metabolic Syndrome');

# %% [markdown]
# Triglyceride levels appear to be a factor in the liklihood of having MetS
# *  The higher the person's triglyceride levels, the higher the chance of MetS
# *  Will use this feature in model

# %% [markdown]
# ### Preprocess for ML

# %% [markdown]
# ##### Load the cleaned dataset

# %%
df.head(2)
# Out:
#        Age     Sex  Marital  Income   Race  Waist   BMI  AlbRating  UricAcid  \
# seqn
# 62161   22    Male   Single  8200.0  White   81.0  23.3          0       4.9
# 62164   44  Female  Married  4500.0  White   80.1  23.2          0       4.5
#
#        Glucose  HDL  Triglycerides       MetS
# seqn
# 62161       92   41             84  No MetSyn
# 62164       82   28             56  No MetSyn

# %% [markdown]
# #### TrainTestSplit

# %%
X=df.drop(columns=['MetS', "AlbRating"], axis=1)
y=df['MetS']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
X.head(1)
# Out:
#        Age   Sex Marital  Income   Race  Waist   BMI  UricAcid  Glucose  HDL  \
# seqn
# 62161   22  Male  Single  8200.0  White   81.0  23.3       4.9       92   41
#
#        Triglycerides
# seqn
# 62161             84

# %% [markdown]
# ##### Prepare for Preprocessing

# %%
#Check for balance with value_counts
y.value_counts(normalize=True)
# Out:
# No MetSyn    0.657643
# MetSyn       0.342357
# Name: MetS, dtype: float64

# %%
X_train.dtypes
# Out:
# Age                int64
# Sex               object
# Marital           object
# Income           float64
# Race              object
# Waist            float64
# BMI              float64
# UricAcid         float64
# Glucose            int64
# HDL                int64
# Triglycerides      int64
# dtype: object

# %%
y_test.head(1)
# Out:
# seqn
# 71097    No MetSyn
# Name: MetS, dtype: object

# %%
#Instantiate the transformers
from sklearn.impute import KNNImputer
scaler=StandardScaler()
ohe = OneHotEncoder(handle_unknown='ignore', sparse_output=False)
impute= KNNImputer(n_neighbors=3)
imputer=SimpleImputer(strategy='mean')
impute_na=SimpleImputer(strategy='constant', fill_value='missing')
#ord_enc = OrdinalEncoder

# %% [markdown]
# catcols= df.select_dtypes('object')#.drop(columns='AlbRating').copy()
# numcols=df.select_dtypes('number')

# %% [markdown]
# catcols.isna().sum()

# %% [markdown]
# numcols.isna().sum()

# %% [markdown]
# ordcols.isna().sum()

# %%
numcols = X_train.select_dtypes('number').columns
num_pipe = make_pipeline(scaler, imputer)
num_tuple = ('numeric', num_pipe, numcols)
num_tuple
# Out:
# ('numeric',
#  Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('simpleimputer', SimpleImputer())]),
#  Index(['Age', 'Income', 'Waist', 'BMI', 'UricAcid', 'Glucose', 'HDL',
#         'Triglycerides'],
#        dtype='object'))

# %%
catcols = X_train.select_dtypes('object').columns
cat_pipe = make_pipeline( ohe, impute_na)
cat_tuple = ('catagorical',cat_pipe, catcols)
cat_tuple
# Out:
# ('catagorical',
#  Pipeline(steps=[('onehotencoder',
#                   OneHotEncoder(handle_unknown='ignore', sparse_output=False)),
#                  ('simpleimputer',
#                   SimpleImputer(fill_value='missing', strategy='constant'))]),
#  Index(['Sex', 'Marital', 'Race'], dtype='object'))

# %% [markdown]
# #Specify order for OrdinalEncoder
# ordcols=X_train['AlbRating']
# ablr_order = ['0', '1', '2']
# ord_enc = OrdinalEncoder(categories='auto')

# %% [markdown]
# #make an ord tuple
# ord_tuple = ('ordinal', ord_enc, ord_cols)
# ord_tuple

# %%
preprocessor= ColumnTransformer([num_tuple,cat_tuple],
                               verbose_feature_names_out=False)
preprocessor
# Out:
# ColumnTransformer(transformers=[('numeric',
#                                  Pipeline(steps=[('standardscaler',
#                                                   StandardScaler()),
#                                                  ('simpleimputer',
#                                                   SimpleImputer())]),
#                                  Index(['Age', 'Income', 'Waist', 'BMI', 'UricAcid', 'Glucose', 'HDL',
#        'Triglycerides'],
#       dtype='object')),
#                                 ('catagorical',
#                                  Pipeline(steps=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False)),
#                                                  ('simpleimputer',
#                                                   SimpleImputer(fill_value='missing',
# ...

# %% [markdown]
# #### Fit and evaluate a default model

# %%
#Create and instance of the model
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
#Create a model pipline
default_pipe= make_pipeline(preprocessor, knn)
default_pipe
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('numeric',
#                                                   Pipeline(steps=[('standardscaler',
#                                                                    StandardScaler()),
#                                                                   ('simpleimputer',
#                                                                    SimpleImputer())]),
#                                                   Index(['Age', 'Income', 'Waist', 'BMI', 'UricAcid', 'Glucose', 'HDL',
#        'Triglycerides'],
#       dtype='object')),
#                                                  ('catagorical',
#                                                   Pipeline(steps=[('onehotencoder',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False)),
# ...

# %%
#Fit the model
default_pipe.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[97], line 2
#       1 #Fit the model
# ----> 2 default_pipe.fit(X_train, y_train)
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\sklearn\pipeline.py:401, in Pipeline.fit(self, X, y, **fit_params)
#     375 """Fit the model.
#     376
#     377 Fit all the transformers one after the other and transform the
#    (...)
#     398     Pipeline with fitted steps.
#     399 """
#     400 fit_params_steps = self._check_fit_params(**fit_params)
# --> 401 Xt = self._fit(X, y, **fit_params_steps)
#     402 with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#     403     if self._final_estimator != "passthrough":
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\sklearn\pipeline.py:359, in Pipeline._fit(self, X, y, **fit_params_steps)
#     357     cloned_transformer = clone(transformer)
# ...

# %%
evaluate_classification(default_pipe, X_train, y_train, X_test, y_test)

# %%
## instantiate the selector with a model.
selector = SelectFromModel(default)

# %%
## Put it in a pipeline
sel_pipe = make_pipeline(transformer,
                         selector,
                         RandomForestClassifier(random_state=42))

# %%
## Fit the pipeline
sel_pipe.fit(X_train, y_train)

# %% [markdown]
# #### Extract and visualize the top 10 features using permutation importance

# %%
## Decide on a number of features to keep
num_features = 10

## Instantiate the feature selector
feat_selector = SequentialFeatureSelector(default, n_features_to_select=num_features,
                                          direction='forward', cv=2,
                                          n_jobs=-1)

## Fit the feature selector
feat_selector.fit(X_train_proc, y_train)

# %% [markdown]
#  Do these features make sense based on the business case?

# %%
# Extract the features suggested by the selector
features_to_keep = feat_selector.support_

## Use the filter to subset the features.
X_train_sel = X_train_proc.loc[:, features_to_keep]
X_test_sel = X_test_proc.loc[:, features_to_keep]

# %%
rf_selected = RandomForestClassifier(random_state=42) rf_selected.fit(X_train_sel, y_train)

# %% [markdown]
# #### Create Explanatory Visualizations for the most important features

# %% [markdown]
# Select 2 out of the top 10 features from your permutation importances and produce explanatory visualizations showing the relationship between the feature and the target.
